# %% [markdown]
# # Lista de Exercícios - Gráficos
#
# Observe as instruções de cada enunciado. Siga os passos do Exercício 1.
#
# As cores das curvas não importam.
#
# Escreva os programas correspondentes na célula abaixo. Finalizando, salve o arquivo como .py ou .ipynb e envie na tarefa.

# %% [markdown]
# **Exercício 1.** Faça o gráfico da função
# $𝑓(𝑥)=sin⁡(𝑥^2)+cos⁡(x^2)$
# entre $−6$ (incluso) e $6$ (não incluso) com incrementos de 0.1.
# Calcule os valores de $𝑓(𝑥)$ para essa faixa.
# Plote o gráfico da função.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Criar a faixa de valores de x
x = np.arange(-6, 6, 0.1)

# Calcular os valores de f(x)
y = np.sin(x**2) + np.cos(x)**2

# Plotar a função
plt.plot(x, y, label='$f(x) = \sin(x^2) + \cos^2(x)$')
plt.title('Gráfico de $f(x) = \sin(x^2) + \cos^2(x)$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Exercício 2.** Faça o gráfico da função $f(x)=2x^3−4x^2+x−5$ para $x$ entre $-3$ e $3$ com incrementos de $0.1$. Calcule os valores de $f(x)$ para essa faixa.
# Plote o gráfico da função.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Criar a faixa de valores de x
x = np.arange(-3, 3, 0.1)

# Calcular os valores de f(x)
y = 2*x**3 - 4*x**2 + x - 5

# Plotar a função
plt.plot(x, y, label='$f(x) = 2*x**3 - 4*x**2 + x - 5 ')
plt.title('Gráfico de $f(x) = 2*x**3 - 4*x**2 + x - 5 ')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Exercício 3:** Faça o gráfico da função $𝑓(𝑥)=𝑎𝑥^2+𝑏𝑥+𝑐$ com valores e intervalo definidos pelo usuário.
# 1. Inicialmente, peça ao usuário para fornecer os valores de $a,b,c,$ o início do intervalo, $r1$, e o fim do intervalo, $r2$.
# 2. Crie uma faixa de valores de $x$ com incrementos de $0.1$ no intervalo fornecido.
# 3. Calcule os valores de $𝑓(𝑥)$ para essa faixa.
# 4. Plote o gráfico da função.

# %%
import numpy as np
import matplotlib.pyplot as plt
#entradas
a =float(input('Digite o valor de a:'))
b=float(input('Digite o valor de b:'))
c=float(input('Digite o valor de c:'))
r1=float(input('Digite o valor de r1:'))
r2=float(input('Digite o valor de r2:'))

# Criar a faixa de valores de x
x = np.arange( r1,r2,  0.1)

# Calcular os valores de f(x)
y = a*x**2 - b*x + c

# Plotar a função
plt.plot(x, y, label='$f(x)= a*x**2 - b*x + c')
plt.title('Gráfico de $f(x) = a*x**2 - b*x + c ')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Digite o valor de a:4
# Digite o valor de b:3
# Digite o valor de c:4
# Digite o valor de r1:5
# Digite o valor de r2:2

# %% [markdown]
#  **Exercício 4.** Faça o gráfico das funções $f_1(x) = sin(ax)$ e $f_2(x) = cos(bx)$ em um intervalo definido pelo usuário.
#
# 1. Inicialmente, peça ao usuário para fornecer os valores de $a,b$  e os valores de início do intervalo, $r1$, e o fim do intervalo, $r2$.
# 2. Crie uma faixa de valores de $x$ com incrementos de $0.1$ no intervalo fornecido.
# 3. Calcule os valores de $𝑓_1(𝑥)$ e $f_2(x)$ para essa faixa.
# 4. Plote o gráfico da função.

# %%
#entrada
a= float(input('Forneça o valor de a: '))
b=float(input('Forneça o valor de b: '))
r1=float(input('Forneça o valor de r1: '))
r2=float(input('Forneça o valor de r2: '))
#valorx
x = np.arange(r1,r2,0.1)
#calculo
y1=np.sin(a*x)
y2=np.cos(b*x)
#grafico
plt.plot(x,y1,label='$f1(x)= sin(a*x)')
plt.plot(x,y2,label='$f1(x)= cos(b*x)')
plt.title('Grafico f1 e f2')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Forneça o valor de a: 7
# Forneça o valor de b: 5
# Forneça o valor de r1: 3
# Forneça o valor de r2: 4
