# %% [markdown]
# Lista 1 - bcc

# %%
#exercicio 2
import math
#entradas
x= float(input("Digite a coordenada X: "))
y=float(input("Digite a coordenada Y: "))
eficiencia = float(input())
combustivel = float(input())

#calculo de distancia
distancia = math.sqrt(x**2 + y**2)

#calculo combustivel
combustivel_necessario = distancia/eficiencia
#saidas
if combustivel >= combustivel_necessario:
    print("S")
else:
    print("N")
# Out:
# Digite a coordenada X: -60.6
# Digite a coordenada Y: 30.5
# 13.7
# 5.0
# S

# %%
#exercicio 5
n = int(input())
print(n)
# Out:
# 5
# 5
